# %% [markdown]
# # L10b: A Deeper Dive into American Options Contract Pricing
# In this lecture, we continue our exploration of American options pricing, building upon the foundational concepts we covered in previous lectures.
#
# > __Learning Objectives:__
# >
# > By the end of this lecture, you should be able to:
# > * __Understand the decision rule for American options:__ Recognize that at each node in the binomial tree, the option holder must decide whether to exercise immediately or hold the option, based on comparing intrinsic value to expected future value.
# > * __Decompose option premiums into components:__ Separate option prices into intrinsic value (immediate exercise value) and extrinsic value (time value) to understand what portion of the premium reflects current value versus future potential.
# > * __Analyze how parameters affect extrinsic value:__ Examine how strike price, time to expiration, and volatility influence the extrinsic value of American options.
#
# Let's get started!
# ___

# %% [markdown]
# ## Examples
# Today, we will be using the following examples to illustrate key concepts:
#
# > [▶ Let's compute the Premium for American Put Options using a binomial lattice](lectures/week-10/L10b/CHEME-5660-L10b-Example-Hull-American-Put-Fall-2025.ipynb). In this example, we'll compute the price of a hypothetical American put option contracts using backward induction over a binomial lattice model, and compare our results to the same contract written as European contract
#
# > [▶ Let's compute the Premium for American Call and Put Options using CRR](CHEME-5660-L10b-Example-AmericanContractsPremium-Fall-2025.ipynb). In this example, we'll compute the price of American call and put option contracts using the Cox-Ross-Rubinstein (CRR) binomial model, and compare our results to observed market prices for AMD options contracts.
#
# > [▶ Let's decompose the premium of an NVDA call contract](lectures/week-10/L10b/CHEME-5660-L10b-Example-NVDA-ExtrinsicValue-Fall-2025.ipynb). In this example, we'll compute the intrinsic and extrinsic values of a call contract, and look at how contract parameters such as the strike price and the days to expiration of the contract influence its extrinsic value.
#
# With these examples in mind, let's review the foundational concepts we'll need.
# ___

# %% [markdown]
# ## Concept Review: CRR Binomial Pricing Model
# American style options contracts allow the holder to exercise the option __at any time__ before or on the expiration date. The standard method to price American options is the Cox, Ross, Rubinstein (CRR) binomial model.
#
# __Reference:__
# * [Cox, J. C.; Ross, S. A.; Rubinstein, M. (1979). "Option pricing: A simplified approach". Journal of Financial Economics. 7 (3): 229. CiteSeerX 10.1.1.379.7582. doi:10.1016/0304-405X(79)90015-1](https://www.sciencedirect.com/science/article/pii/0304405X79900151)
#
# The CRR model assumes that the movement of the share price of the underlying asset can be modeled as a binomial tree, where at each time step, the price can either move up by a factor of $u$ or down by a factor of $d$. The probability of an up move is the __risk-neutral probability__ $q$, and the probability of a down move is $(1-q)$.
#
# The __risk-neutral probability__ $q$ is calculated as:
# $$
# \boxed{
# \begin{align*}
# q = \frac{\mathcal{D}_{1,0}\left(\bar{r}\right) - d}{u - d}\quad\blacksquare
# \end{align*}}
# $$
# where $\mathcal{D}_{1,0}\left(\bar{r}\right)$ is the discount factor for one time step at the risk-free rate $\bar{r}$, and the up and down factors $u$ and $d$ are determined based on the volatility of the underlying asset and the time step size:
# $$
# \boxed{
# \begin{align*}
# u &= e^{\sigma \sqrt{\Delta t}} \\
# d &= e^{-\sigma \sqrt{\Delta t}}
# \end{align*}}
# $$
#
# ### Decision-Rule for American Options
# The key difference between American and European options is the ability to exercise the option at any time before expiration. This introduces an additional decision-making layer in the pricing process.
#
# >__Decision Rule__: At each node in the binomial tree, the holder of an American option must decide whether to exercise the option immediately or to hold onto it for potential future gains. The decision is based on comparing the immediate exercise value with the expected value of holding the option discounted back to the present value.
#
# Let's look at a hypothetical example from Chapter 13 of Hull to illustrate this concept.
#
# > __Example__
# >
# > Consider a put contract. The contract's strike price is K = 52 USD/share on a stock whose current price is $S_{0}$ = 50 USD/share. There are two time steps of 1 year each; in each period, the stock price moves by u = 1.2 or down by d =0.8. The probability of an up move is p = 0.6282. Let the risk-free interest rate be 5%.
#
# What is the price of the American and European put option contracts?

# %% [markdown]
# <div>
#     <center>
#         <img src="figs/Fig-HullExample-American-v-European-Schematic.png" width="800"/>
#     </center>
# </div>

# %% [markdown]
# > [▶ Let's compute the Premium for an American Put Options using a binomial lattice](lectures/week-10/L10b/CHEME-5660-L10b-Example-Hull-American-Put-Fall-2025.ipynb). In this example, we'll compute the price of a hypothetical American put option contracts using backward induction over a binomial lattice model, and compare our results to the same contract written as European contract
#
# ___

# %% [markdown]
# ## Compute the Price of an American Call and Put Option Contract
# Now that we've explored the decision-making process for American options through the Hull example, let's apply these concepts to real market data. We'll compute the price of an American call and put option contract using the CRR binomial model and see how well the model describes observed market behavior.
#
# We'll consider AMD options contracts from our dataset, and see if we can replicate the observed market prices for the contracts as a function of strike price.
#
# > __Example__
# >
# > [▶ Let's compute the Premium for American Call and Put Options using CRR](CHEME-5660-L10b-Example-AmericanContractsPremium-Fall-2025.ipynb). In this example, we'll compute the price of American call and put option contracts using the Cox-Ross-Rubinstein (CRR) binomial model, and compare our results to observed market prices for AMD options contracts.
#
# Having seen how the CRR model performs against market data, let's now explore what drives the value of American options.
# ___

# %% [markdown]
# ## Extrinsic versus Intrinsic Value of American Options
#
# Building on our understanding of American option pricing, it's important to distinguish between __intrinsic__ and __extrinsic__ value. What do these terms mean in the context of American options?
#
# The premium (price) of an American option can be broken down into two components: intrinsic value and extrinsic value.
#
# * __Intrinsic Value__: The intrinsic value of an American option is the __immediate exercise value__. For a call option, it's calculated as $\max(0, S - K)$, where $S$ is the current stock price and $K$ is the strike price. For a put option, it's $\max(0, K - S)$.
# * __Extrinsic Value__: The extrinsic value, also known as time value, represents the additional value of the option based on the potential for future price movements before expiration. It is calculated as the difference between the total option price and its intrinsic value.
#
# The extrinsic value $E_{V}(t)$ can be expressed mathematically as:
# $$
# \boxed{
# \begin{align*}
# E_{V}(t) = \text{Option Price} - \text{Intrinsic Value}\quad\blacksquare
# \end{align*}}
# $$
# or in expanded form:
# $$
# \boxed{
# \begin{align*}
# E_{V}(t) &= \begin{cases}
# \mathcal{P}_{c}(K,S(0)) - \max(0, S(t) - K) & \text{(for Call Options)} \\
# \mathcal{P}_{p}(K,S(0)) - \max(0, K - S(t)) & \text{(for Put Options)}
# \end{cases}
# \end{align*}}
# $$
# This creates an interesting edge case: when the option is __out of the money__, i.e., the option has no intrinsic value, the entire option price is extrinsic value. Why would we be willing to pay for an option that has no intrinsic value?
#
# > __Why do people pay money for something that is "worthless"?__ The answer lies in the potential for future price movements. Even if an option is currently out of the money, there is still a chance that the underlying asset's price could move favorably before expiration, making the option valuable.
#
# As time moves towards expiration, the extrinsic value of an option tends to decrease, a phenomenon known as __time decay.__ This is because there is less time for the underlying asset's price to move in a favorable direction.
#
# Let's look at some current NVDA option contracts in the market and discuss their intrinsic and extrinsic values.
#
# > __Example__
# >
# > [▶ Let's decompose the premium of an NVDA call contract](lectures/week-10/L10b/CHEME-5660-L10b-Example-NVDA-ExtrinsicValue-Fall-2025.ipynb). In this example, we'll compute the intrinsic and extrinsic values of a call contract, and look at how contract parameters such as the strike price and the days to expiration of the contract influence its extrinsic value.
#
# ___

# %% [markdown]
# ## Summary
# This lecture explored how American options are priced using the CRR binomial model and how to decompose option prices into intrinsic and extrinsic components.
#
# > __Key Takeaways:__
# >
# > * __Binomial trees enable American option pricing:__ The CRR model creates a discrete price lattice where at each node, the holder decides whether to exercise immediately or hold the option, making backward induction necessary to compute prices.
# > * __Intrinsic and extrinsic value tell different stories:__ Intrinsic value represents the immediate exercise value, while extrinsic value (time value) captures the potential for favorable price movement before expiration.
# > * __Extrinsic value depends on multiple factors:__ Time to expiration, volatility, and moneyness (relationship between stock price and strike price) all influence how much extrinsic value an option possesses, with longer-dated options typically carrying more extrinsic value than shorter-dated ones.
#
# Understanding how to separate and interpret option value components provides insight into option pricing dynamics and the value of time in derivative contracts.
#
# ___

# %% [markdown]
# ## Disclaimer and Risks
# __This content is offered solely for training and informational purposes__. No offer or solicitation to buy or sell securities or derivative products or any investment or trading advice or strategy is made, given, or endorsed by the teaching team.
#
# __Trading involves risk__. Carefully review your financial situation before investing in securities, futures contracts, options, or commodity interests. Past performance, whether actual or indicated by historical tests of strategies, is no guarantee of future performance or success. Trading is generally inappropriate for someone with limited resources, investment or trading experience, or a low-risk tolerance. Only risk capital that is not required for living expenses should be used.
#
# __You are fully responsible for any investment or trading decisions you make__. Such decisions should be based solely on evaluating your financial circumstances, investment or trading objectives, risk tolerance, and liquidity needs.
#
# ___
